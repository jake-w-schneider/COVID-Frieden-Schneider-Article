# %% [markdown]
# <b>Op-Ed Article: Did COVID Kill Global Capitalism?</b><br>
# <i>Jeffry Frieden & Jake Schneider </i><br>
# September 2020

# %% [markdown]
# ----

# %% [markdown]
# <b>Load Libraries</b>

# %%
#Import libraries
import sys
import pandas as pd
from datetime import date, datetime, time, timedelta
import pendulum
import json
import requests
import numpy as np
import math

import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(style='ticks', context='talk')

from matplotlib.offsetbox import AnchoredText
from sklearn import linear_model
from sklearn.metrics import r2_score
import statsmodels.api as sm
#import fbprophet

import statistics 
from statistics import mode 

from collections import OrderedDict 

from pandas import Grouper

import warnings
import itertools

from matplotlib.backends.backend_pdf import PdfPages
from fpdf import FPDF
from PIL import Image

# %% [markdown]
# ----

# %% [markdown]
# <b>Load Data</b>

# %%
# Load Data from World Bank
# Data available from: https://data.worldbank.org/indicator/BX.KLT.DINV.WD.GD.ZS
# Data available from: https://data.worldbank.org/indicator/NE.TRD.GNFS.ZS

fdi_df = pd.read_csv('Data/API_BX/FDI_WB.csv')
trade_df = pd.read_csv('Data/API_NE/Trade_WB.csv')
df = pd.read_csv('Data/Covid Frieden Schneider Data.csv')

# %%
# View FDI Data

fdi_df.head()
# Out:
#   Country Name Country Code  \
# 0        Aruba          ABW
# 1  Afghanistan          AFG
# 2       Angola          AGO
# 3      Albania          ALB
# 4      Andorra          AND
#
#                                       Indicator Name        Indicator Code  \
# 0  Foreign direct investment, net inflows (% of GDP)  BX.KLT.DINV.WD.GD.ZS
# 1  Foreign direct investment, net inflows (% of GDP)  BX.KLT.DINV.WD.GD.ZS
# 2  Foreign direct investment, net inflows (% of GDP)  BX.KLT.DINV.WD.GD.ZS
# 3  Foreign direct investment, net inflows (% of GDP)  BX.KLT.DINV.WD.GD.ZS
# 4  Foreign direct investment, net inflows (% of GDP)  BX.KLT.DINV.WD.GD.ZS
#
#    1960  1961  1962  1963  1964  1965  ...      2010       2011       2012  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN  ...  7.812573  19.145486 -12.415693
# 1   NaN   NaN   NaN   NaN   NaN   NaN  ...  1.203125   0.293038   0.284096
# 2   NaN   NaN   NaN   NaN   NaN   NaN  ... -3.851110  -2.704875  -1.143768
# ...

# %%
# View Trade Data

trade_df.head()
# Out:
#   Country Name Country Code    Indicator Name  Indicator Code       1960  \
# 0        Aruba          ABW  Trade (% of GDP)  NE.TRD.GNFS.ZS        NaN
# 1  Afghanistan          AFG  Trade (% of GDP)  NE.TRD.GNFS.ZS  11.157027
# 2       Angola          AGO  Trade (% of GDP)  NE.TRD.GNFS.ZS        NaN
# 3      Albania          ALB  Trade (% of GDP)  NE.TRD.GNFS.ZS        NaN
# 4      Andorra          AND  Trade (% of GDP)  NE.TRD.GNFS.ZS        NaN
#
#        1961       1962       1963       1964       1965  ...        2010  \
# 0       NaN        NaN        NaN        NaN        NaN  ...  138.607151
# 1  12.55061  14.227644  26.035511  26.944448  32.671083  ...   52.579600
# 2       NaN        NaN        NaN        NaN        NaN  ...  104.123630
# 3       NaN        NaN        NaN        NaN        NaN  ...   76.543355
# 4       NaN        NaN        NaN        NaN        NaN  ...         NaN
#
#          2011        2012        2013        2014        2015        2016  \
# ...

# %%
# View DF

df.head()
# Out:
#    Year  Trade (% of GDP)  Foreign direct investment, net inflows (% of GDP)
# 0  1970         27.303478                                           0.486561
# 1  1971         27.343756                                           0.472474
# 2  1972         27.465059                                           0.425347
# 3  1973         30.415485                                           0.483502
# 4  1974         35.606453                                           0.498238

# %%
# Convert to Time Series

df["Year"] = pd.to_datetime(df["Year"], format='%Y')

# %%
# View DF

df.head()
# Out:
#         Year  Trade (% of GDP)  \
# 0 1970-01-01         27.303478
# 1 1971-01-01         27.343756
# 2 1972-01-01         27.465059
# 3 1973-01-01         30.415485
# 4 1974-01-01         35.606453
#
#    Foreign direct investment, net inflows (% of GDP)
# 0                                           0.486561
# 1                                           0.472474
# 2                                           0.425347
# 3                                           0.483502
# 4                                           0.498238

# %% [markdown]
# <b>Create Graphic</b>

# %%
# Will not work --> Need to find the code

groups = df.groupby(Grouper(freq='A'))
years = DataFrame()
for name, group in groups:
    years[name.year] = group.values
years.plot(subplots=True, legend=False)
pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-213c9bc54250> in <module>
# ----> 1 groups = df.groupby(Grouper(freq='A'))
#       2 years = DataFrame()
#       3 for name, group in groups:
#       4     years[name.year] = group.values
#       5 years.plot(subplots=True, legend=False)
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed)
#    5808             group_keys=group_keys,
#    5809             squeeze=squeeze,
# -> 5810             observed=observed,
#    5811         )
#    5812
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated)
#     407                 sort=sort,
# ...
